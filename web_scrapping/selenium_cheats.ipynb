# %% [markdown]
# # Selenium
# ---
#
# Biblioteca do Python (também de outras linguagens como #C) para *web scrapping*
#
# ## Instalação
#
# 1. `pip install selenium`
# 2. Baixar o [Chrome Driver](https://sites.google.com/a/chromium.org/chromedriver/home) (versão Windows 32-bits serve para 64-bits também)
#
#
# ## Como usar
#
# - **[Navigating - Selenium Python](https://selenium-python.readthedocs.io/navigating.html)**
# - **[Locating elements - Selenium Python](https://selenium-python.readthedocs.io/locating-elements.html)**

# %% [markdown]
# ## Exemplo
#
# ### Acessando a página e buscando
#
# #### SelectorGadget
# Vamos acessar a página do G1 e buscar por um conteúdo. É importante inspecionar a página para saber os nomes de classes ou elementos de interesse. Isso pode ser feito com a extensão [SelectorGadget](https://chrome.google.com/webstore/detail/selectorgadget/mhjhnkcfbdhnjickkkdbjoemdmbfginb).
#
# - Uma vez instalada, basta buscar a extensão no canto superior direito e irá aparecer o menu destacado em branco.
# - Clique na tela no local que você deseja e selecione "XPath" para descobrir o caminho daquele elemento.
# - Copie esse caminho para a função `find_element_by_xpath` que será utilizada no código
#
# ![Selector - G1](./figures/g1_selector.png)
#
# #### Inspecionando a página
#
# - Outra opção é mais "manual", buscando no código fonte da página: Na figura abaixo está destacada (código em azul) a área referente à busca, mais especificamente (código em cinza) a classe do `input`
#
# ![Inspecionar - G1](./figures/g1_inspecionar.png)
#
# * Aqui podemos observar que a classe do `input` tem um id chamado `busca_campo`, então vamos localizá-lo (para saber mais como localizar elementos, ver link em [Como usar](#Como-usar)). Aqui basta clicar com o botão direito no element o `input` e em seguida `Copiar > Copiar XPath`
#
# ![Localizar elemento - G1](./figures/g1_xpath.png)

# %%
from selenium import webdriver

webpage = r'https://g1.globo.com/' # edit me

# mudar para o local onde você extraiu o chromedriver
driver = webdriver.Chrome('C:\\Users\\Elogroup\\Documents\\chromedriver_win32\\chromedriver.exe')
driver.maximize_window()

# é bom colocar o tempo (segundos) de espera caso vá fazer muitas requisições
driver.implicitly_wait(5)

# capturando o conteúdo da página
driver.get(webpage)

# identificando o campo de busca com o XPath copiado
sbox = driver.find_element_by_xpath("//*[@id=\"busca-campo\"]")

# preenchendo com o termo a ser buscado e enter!
from selenium.webdriver.common.keys import Keys
sbox.send_keys("ciencia de dados", Keys.ENTER)

content = driver.page_source

# %% [markdown]
# * No caso da página ter um botão para submeter o conteúdo, podemos usar o código abaixo

# %% [raw]
# # identificando o campo de busca com o XPath copiado
# sbox = driver.find_element_by_xpath("//*[@id=\"busca-campo\"]")
#
# # preenchendo o termo a ser buscado
# sbox.send_keys("data science")
#
# # submetendo a busca
# submit = driver.find_element_by_name("[nome do elemento submit]")
# submit.click()

# %% [markdown]
# * No caso do conteúdo estar dentro de um `frame` (classe chamada `iframe`), deve-se mudar o driver para esse local como abaixo antes de fazer a busca

# %% [raw]
# driver.switch_to_frame(driver.find_element_by_name("iframe"))
#
# # todo o resto igual
# sbox = driver.find_element_by ...

# %% [markdown]
# * No caso do conteúdo ser gerado numa nova janela, devemos mudar o `driver` para a nova janela também

# %% [raw]
# # lista de janelas (tanto a primária quanto as demais abertas no processo)
# windows = driver.window_handle
#
# # selecione a janela pelo índice (0 é a janela da url, 1 é a janela aberta após a principal, e assim sucessivamente)
# driver.switch_to_window(windows[1])
#
# # todo o resto igual
# sbox = driver.find_element_by ...

# %% [markdown]
# ### Lendo o conteúdo com `Beautiful Soup`

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup
#  <img class="logo-produto logo-mobile" src="//s.glbimg.com/jo/g1/i/logo_g1_busca.jpg"/>
#  <img class="logo-produto logo-retina-desktop" src="//s.glbimg.com/jo/g1/i/logo_g1_busca.jpg"/>
#  <img class="logo-produto logo-retina-mobile" src="//s.glbimg.com/jo/g1/i/logo_g1_busca.jpg"/>
#  <span></span>
#  </a>
#  </div>
#  <div class="search-header__menu-area-smart">
#  <div class="main-container">
#  <div class="left-container">
#  <div class="menu-area-smart">
#  <div class="menu-button-smart" onclick="javascript:document.dispatchEvent(new CustomEvent('glb.mobileMenuV2.open'));">
#  <div class="burger-smart">
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="center-container">
#  <a href="https://g1.globo.com/" title="https://g1.globo.com/">
#  <svg class="product-logo g1-logo" fill="#fff" viewbox="0 0 516 308" xmlns="http://www.w3.org/2000/svg"><title>G1</title><path d="M0 208.716C0 263.56 50.353 308 112.558 308h224.66V118.447H212.173v94.417h-59.39c-15.54 0-28.157-11.125-28.157-24.828V95.97c0-13.68 7.63-24.826 23.16-24.826h100.467L304.525.47H112.558C50.353.47 0 49.482 0 104.34v104.376zM387.186 308H512V24.832C512 11.13 499.408 0 483.868 0h-123.05l-56.292 70.95h54.523c15.538 0 28.136 11.123 28.136 24.817V308z" fill="currentColor" fill-rule="evenodd"></path></svg>
#  </a>
#  </div>
#  <div class="right-container">
#  <svg class="search-icon" fill="#fff" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M15.5 14h-.79l-.28-.27C15.41 12.59 16 11.11 16 9.5 16 5.91 13.09 3 9.5 3S3 5.91 3 9.5 5.91 16 9.5 16c1.61 0 3.09-.59 4.23-1.57l.27.28v.79l5 4.99L20.49 19l-4.99-5zm-6 0C7.01 14 5 11.99 5 9.5S7.01 5 9.5 5 14 7.01 14 9.5 11.99 14 9.5 14z"></path>
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  </svg>
#  </div>
#  </div>
#  </div>
#  <form action="." class="search-form" method="GET" name="search">
#  <div class="search-form__search-field">
#  <label class="search-form__search-field__icon" for="q"></label>
#  <svg class="search-form__search-icon" fill="#999" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M15.5 14h-.79l-.28-.27C15.41 12.59 16 11.11 16 9.5 16 5.91 13.09 3 9.5 3S3 5.91 3 9.5 5.91 16 9.5 16c1.61 0 3.09-.59 4.23-1.57l.27.28v.79l5 4.99L20.49 19l-4.99-5zm-6 0C7.01 14 5 11.99 5 9.5S7.01 5 9.5 5 14 7.01 14 9.5 11.99 14 9.5 14z"></path>
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  </svg>
#  <input autocapitalize="off" autocomplete="off" autocorrect="off" class="search-form__search-field__input search-form__search-field__input-filled" id="q" mozactionhint="search" name="q" placeholder="BUSCAR" spellcheck="false" tabindex="1" type="text" value="ciencia de dados"/>
#  <input class="search-form__search-field__autocomplete" id="autocomplete-input" tabindex="-1" type="text"/>
#  <span class="search-form__clean-button" style="display: inline;"></span>
#  <button class="search-form__cancel-button__smart" type="button">CANCELAR</button>
#  </div>
#  </form>
#  </div>
#  </div>
#  </header>, '\n', <div data-react-props='{"showServicesHeaderActive": true, "dateRangeFilter": {"start": null, "selected": false, "end": null, "target": "?q=ciencia+de+dados", "label": "DE  A "}, "species": [{"selected": true, "target": "?q=ciencia+de+dados", "allSpecies": true, "label": "Todos resultados"}, {"selected": false, "target": "?q=ciencia+de+dados&amp;species=not%C3%ADcias", "label": "not\u00edcias"}, {"selected": false, "target": "?q=ciencia+de+dados&amp;species=fotos", "label": "fotos"}, {"selected": false, "target": "?q=ciencia+de+dados&amp;species=v%C3%ADdeos", "label": "v\u00eddeos"}, {"selected": false, "target": "?q=ciencia+de+dados&amp;species=blogs", "label": "blogs"}], "sortFilters": [{"selected": true, "target": "?q=ciencia+de+dados&amp;order=recent", "label": "Recentes"}, {"selected": false, "target": "?q=ciencia+de+dados&amp;order=relevant", "label": "Relevantes"}], "dateFilters": [{"default": true, "selected": true, "target": "?q=ciencia+de+dados", "label": "Em qualquer data"}, {"selected": false, "target": "?q=ciencia+de+dados&amp;from=now-1h", "label": "Na \u00faltima hora"}, {"selected": false, "target": "?q=ciencia+de+dados&amp;from=now-1d", "label": "Nas \u00faltimas 24 horas"}, {"selected": false, "target": "?q=ciencia+de+dados&amp;from=now-1w", "label": "Na \u00faltima semana"}, {"selected": false, "target": "?q=ciencia+de+dados&amp;from=now-1M", "label": "No \u00faltimo m\u00eas"}, {"selected": false, "target": "?q=ciencia+de+dados&amp;from=now-1y", "label": "No \u00faltimo ano"}]}' id="search-filter-component"><div><div class="search-filter-component"><div class="filter-container"><div class="filter-desktop filters"><div class="filters__container"><span class="filters__item filters__label">Exibindo</span><div class="filters__dropdown filters__item"><a class="filters__dropdown__link"><span class="filters__selected-label filter-product-color">Todos resultados</span><span class="filters__dropdown__icon"></span></a><ul class="filters__dropdown__list"><li class="filters__dropdown__list__header">Filtrar por</li><li class="filters__dropdown__list__item__selected"><span class="advanced-filters__dropdown__text">Todos resultados</span></li><li class="filters__dropdown__list__item"><span class="advanced-filters__dropdown__text">notícias</span></li><li class="filters__dropdown__list__item"><span class="advanced-filters__dropdown__text">fotos</span></li><li class="filters__dropdown__list__item"><span class="advanced-filters__dropdown__text">vídeos</span></li><li class="filters__dropdown__list__item"><span class="advanced-filters__dropdown__text">blogs</span></li></ul></div><span class="filters__item filters__label">Mais</span><div class="filters__dropdown filters__item"><a class="filters__dropdown__link"><span class="filters__selected-label filter-product-color">Recentes</span><span class="filters__dropdown__icon"></span></a><ul class="filters__dropdown__list"><li class="filters__dropdown__list__header">Ordenar por mais</li><li class="filters__dropdown__list__item__selected"><span class="advanced-filters__dropdown__text">Recentes</span></li><li class="filters__dropdown__list__item"><span class="advanced-filters__dropdown__text">Relevantes</span></li></ul></div></div><div class="filters__advanced-date-filter"><div class="filters__dropdown filters__item"><a class="filters__dropdown__link"><span class="filters__selected-label filter-product-color">Filtrar por Data</span><span class="filters__dropdown__icon"></span></a><ul class="filters__dropdown__list__right"><li class="filters__dropdown__list__header">Por período</li><li class="filters__dropdown__list__item__selected"><span class="advanced-filters__dropdown__text">Em qualquer data</span></li><li class="filters__dropdown__list__item"><span class="advanced-filters__dropdown__text">Na última hora</span></li><li class="filters__dropdown__list__item"><span class="advanced-filters__dropdown__text">Nas últimas 24 horas</span></li><li class="filters__dropdown__list ...
#  <div class="results results--" data-request-time="0.305068016052">
#  <div class="results__content">
#  <ul class="results__list">
#  <li class="widget widget--card widget--navigational" data-position="0">
#  <div class="widget--navigational__page">
#  <a class="widget--navigational__title cor-produto" href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=0&amp;r=1562807439569&amp;u=https%3A%2F%2Fg1.globo.com%2Fciencia-e-saude%2F&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=1514ffc59270d9ae4ea0917b55a815dc">Ciência e Saúde</a>
#  <p class="widget--navigational__publisher">G1</p>
#  <p class="widget--navigational__description">As notícias sobre pesquisas e descobertas científicas, o espaço e o clima, além de dicas de como viver bem e melhor</p>
#  </div>
#  </li>
#  <li class="widget widget--card widget--info" data-position="1">
#  <div class="widget--info__meta--card">
#  <span>G1</span>
#  <span>•</span>
#  <span>há 1 dia</span>
#  </div>
#  <div class="widget--info__media-container">
#  <a class="widget--info__media" href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=1&amp;r=1562807439836&amp;u=https%3A%2F%2Fg1.globo.com%2Fpa%2Fsantarem-regiao%2Fnoticia%2F2019%2F07%2F09%2Fprograma-de-pos-graduacao-em-ciencias-da-saude-da-ufopa-abre-vagas-para-turma-do-segundo-semestre.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=b36671749dd20c5cc9415044f89a2053">
#  <img src="//s2.glbimg.com/93brn_88bSZU9riUpO8BeqnKoSQ=/346x195/smart/http%3A//i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2019/k/7/tLVDMjQe6zrg99GENRLw/foto-1-materia-areas-de-atuacao-engenharia-ambiental.jpg"/>
#  </a>
#  </div>
#  <div class="widget--info__text-container">
#  <div class="widget--info__header">G1</div>
#  <a href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=1&amp;r=1562807439838&amp;u=https%3A%2F%2Fg1.globo.com%2Fpa%2Fsantarem-regiao%2Fnoticia%2F2019%2F07%2F09%2Fprograma-de-pos-graduacao-em-ciencias-da-saude-da-ufopa-abre-vagas-para-turma-do-segundo-semestre.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=b36671749dd20c5cc9415044f89a2053">
#  <div class="widget--info__title product-color">
#          Programa de pós-graduação em ciências da saúde da Ufopa abre vagas para turma do segundo semestre
#        </div>
#  <p class="widget--info__description"><span>Mestrado em <em>ciência</em> da saúde em Santarém
#  Ares Soares/Unifor
#  O Programa de Pós-Graduação em <em>Ciências</em> da Saúde (Ppgcsa...</span> — <span>... 2019.2 do Mestrado em <em>Ciências</em> da Saúde.
#  Podem participar da seleção candidatos graduados em curso de nível superior em <em>Ciências</em>...</span></p>
#  <div class="widget--info__meta">há 1 dia</div>
#  </a>
#  </div>
#  </li>
#  <li class="widget widget--card widget--info widget--ad" data-position="2">
#  <div class="widget--info__meta--card">
#  <span>G1</span>
#  <span>•</span>
#  <span>há 2 dias</span>
#  </div>
#  <div class="widget--info__media-container">
#  <a class="widget--info__media" href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=2&amp;r=1562807439843&amp;u=https%3A%2F%2Fg1.globo.com%2Fespecial-publicitario%2Finovacao%2Fnoticia%2F2019%2F07%2F05%2Fcomo-a-inteligencia-artificial-ja-esta-presente-na-sua-vida.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=a9a52d5c272aeb6509a0d4bc22c33231">
#  <img src="//s2.glbimg.com/X3jJlWfMNw594k65IXB86UlZuAE=/346x195/smart/http%3A//i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2019/w/J/aBbN5ASbaaYauVDxn1og/inovacao-inteligencia-artifical-1.jpg"/>
#  </a>
#  </div>
#  <div class="widget--info__text-container">
#  <p class="widget--info__ad-label">Especial publicitário</p>
#  <a href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=2&amp;r=1562807439845&amp;u=https%3A%2F%2Fg1.globo.com%2Fespecial-publicitario%2Finovacao%2Fnoticia%2F2019%2F07%2F05%2Fcomo-a-inteligencia-artificial-ja-esta-presente-na-sua-vida.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=a9a52d5c272aeb6509a0d4bc22c33231">
#  <div class="widget--info__title product-color widget--info__title--ad">
#          Como a inteligência artificial já está presente na sua vida
#        </div>
#  <p class="widget--info__description"><span>... em computadores. Por meio da análise de milhões de <em>dados</em>, as máquinas são capazes de perceber variáveis, tomar decisões e resolver...</span> — <span>... Ponce de Leon Ferreira Carvalho, do Instituto de <em>Ciências</em> Matemáticas e de Computação da Universidade de São Paulo (USP), membro...</span></p>
#  <div class="widget--info__meta">há 2 dias</div>
#  </a>
#  </div>
#  </li>
#  <li class="widget widget--card widget--info" data-position="3">
#  <div class="widget--info__meta--card">
#  <span>G1</span>
#  <span>•</span>
#  <span>02/07/2019 08h00</span>
#  </div>
#  <div class="widget--info__media-container">
#  <a class="widget--info__media widget--info__media--video" href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=3&amp;r=1562807439848&amp;u=https%3A%2F%2Fg1.globo.com%2Fnatureza%2Fdesafio-natureza%2Fnoticia%2F2019%2F07%2F02%2Fturismo-tecnologia-e-ciencia-cidada-ja-identificaram-pelo-menos-400-oncas-pintadas-no-pantanal.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=763c1fa572f1070e6d71d2a934744742">
#  <img src="//s2.glbimg.com/itinKq8ZQXB1RvlLl8H1XxzHQgQ=/346x195/smart/http%3A//i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2019/p/r/KrmWtQR3uUhaBpMKUfIw/founder-of-jip.jpg"/>
#  </a>
#  </div>
#  <div class="widget--info__text-container">
#  <div class="widget--info__header">G1</div>
#  <a href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=3&amp;r=1562807439851&amp;u=https%3A%2F%2Fg1.globo.com%2Fnatureza%2Fdesafio-natureza%2Fnoticia%2F2019%2F07%2F02%2Fturismo-tecnologia-e-ciencia-cidada-ja-identificaram-pelo-menos-400-oncas-pintadas-no-pantanal.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=763c1fa572f1070e6d71d2a934744742">
#  <div class="widget--info__title product-color">
#          Turismo, tecnologia e 'ciência cidadã' já identificaram pelo menos 400 onças-pintadas no Pantanal
#        </div>
#  <p class="widget--info__description"><span>... pantaneiras. Um artigo publicado em 2018 por um pesquisador mexicano, usando <em>dados</em> de 117 estudos com armadilhas fotográficas entre 2002...</span> — <span>... contam 'causos' reais com onças-pintadas
#  Tecnologia e '<em>ciência</em> cidadã'
#  O levantamento do G1 foi feito junto a seis iniciativas...</span></p>
#  <div class="widget--info__meta">02/07/2019 08h00</div>
#  </a>
#  </div>
#  </li>
#  <li class="widget widget--card widget--info" data-position="4">
#  <div class="widget--info__meta--card">
#  <span>G1</span>
#  <span>•</span>
#  <span>há 2 dias</span>
#  </div>
#  <div class="widget--info__media-container">
#  <a class="widget--info__media" href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=4&amp;r=1562807439855&amp;u=https%3A%2F%2Fg1.globo.com%2Fciencia-e-saude%2Fviva-voce%2Fnoticia%2F2019%2F07%2F08%2Ftomar-leite-fortalece-os-ossos.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=8aa0d04f4e5eb9c43c6f344094054c10">
#  <img src="//s2.glbimg.com/0lAHnVmxvBP_bn_1X82uADe_K_Q=/346x195/smart/http%3A//i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2019/s/1/ekjogrQOGjMl0E4OatYA/milk-2474993-1920.jpg"/>
#  </a>
#  </div>
#  <div class="widget--info__text-container">
#  <div class="widget--info__header">G1</div>
#  <a href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=4&amp;r=1562807439858&amp;u=https%3A%2F%2Fg1.globo.com%2Fciencia-e-saude%2Fviva-voce%2Fnoticia%2F2019%2F07%2F08%2Ftomar-leite-fortalece-os-ossos.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=8aa0d04f4e5eb9c43c6f344094054c10">
#  <div class="widget--info__title product-color">
#          Tomar leite fortalece os ossos?
#        </div>
#  <p class="widget--info__description"><span>..., a mesma equipe na Nova Zelândia combinou os <em>dados</em> de 51 estudos randomizados controlados para avaliar se os benefícios superavam eventuais...</span> — <span>...
#  Quando diferentes países examinaram os mesmos <em>dados</em>, chegaram a conclusões muito diferentes sobre a ingestão diária recomendada de cálcio...</span></p>
#  <div class="widget--info__meta">há 2 dias</div>
#  </a>
#  </div>
#  </li>
#  <li class="widget widget--card widget--info" data-position="5">
#  <div class="widget--info__meta--card">
#  <span>G1</span>
#  <span>•</span>
#  <span>há 6 dias</span>
#  </div>
#  <div class="widget--info__text-container">
#  <div class="widget--info__header">G1</div>
#  <a href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=5&amp;r=1562807439861&amp;u=https%3A%2F%2Fg1.globo.com%2Fsp%2Fsao-paulo%2Fnoticia%2F2019%2F07%2F03%2Fprefeitura-de-sp-lanca-novo-indice-para-avaliar-educacao-municipal.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=9f65c5099ac6d7b4ba57ffab9d0e0f73">
#  <div class="widget--info__title product-color">
#          Prefeitura de SP lança novo índice para avaliar educação municipal
#        </div>
#  <p class="widget--info__description"><span>... de Desenvolvimento da Educação Paulistana (Idep) vai considerar o desempenho dos estudantes na Prova São Paulo e também <em>dados</em> territoriais...</span> — <span>... também vai considerar <em>Ciências</em> da Natureza.
#  "O município sai na frente com a criação desse índice. Está de acordo com a base comum...</span></p>
#  <div class="widget--info__meta">há 6 dias</div>
#  </a>
#  </div>
#  </li>
#  <li class="widget widget--card widget--info widget--ad" data-position="6">
#  <div class="widget--info__meta--card">
#  <span>G1</span>
#  <span>•</span>
#  <span>30/05/2019 17h13</span>
#  </div>
#  <div class="widget--info__media-container">
#  <a class="widget--info__media" href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=6&amp;r=1562807439864&amp;u=https%3A%2F%2Fg1.globo.com%2Fce%2Fceara%2Fespecial-publicitario%2Funifor%2Fensinando-e-aprendendo%2Fnoticia%2F2019%2F05%2F29%2Funifor-abre-vagas-para-pesquisadores-em-ciencia-de-dados-e-inteligencia-artificial.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=084c7deba3c92283ac2950870dba5d28">
#  <img src="//s2.glbimg.com/Oyv2f4i8uuK_GznT_x6jfhm1EIc=/346x195/smart/http%3A//i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2019/v/o/5CAB7NSKWrBdG2el9ybA/foto-materia-vaga-pesquisadores-nucleo-ciencia-de-dados-unifor.jpg"/>
#  </a>
#  </div>
#  <div class="widget--info__text-container">
#  <p class="widget--info__ad-label">Especial publicitário</p>
#  <a href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p
ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=b31ad4e30cc6772c31d73849c013ac82">
#  <div class="widget--info__title product-color widget--info__title--ad">
#          Unifor promove o I Ciência e Inovação: evento amplia o alcance da pesquisa científica desenvolvida na instituição
#        </div>
#  <p class="widget--info__description"><span>..., e um dos convidados do evento.
#  University of Toronto
#  A Universidade de Fortaleza (Unifor) promove, dia 7 de agosto, o evento <em>Ciência</em>...</span> — <span>.... Será uma oportunidade para público cearense conhecer os desafios da <em>ciência</em> em temas distintos como biotecnologia, saúde coletiva...</span></p>
#  <div class="widget--info__meta">24/06/2019 16h30</div>
#  </a>
#  </div>
#  </li>
#  <li class="widget widget--card widget--info" data-position="9">
#  <div class="widget--info__meta--card">
#  <span>G1</span>
#  <span>•</span>
#  <span>há 3 horas</span>
#  </div>
#  <div class="widget--info__media-container">
#  <a class="widget--info__media widget--info__media--video" href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=9&amp;r=1562807439886&amp;u=https%3A%2F%2Fg1.globo.com%2Fsp%2Fsao-carlos-regiao%2Fnoticia%2F2019%2F07%2F10%2Fworkshop-em-sao-carlos-reune-professores-e-alunos-para-resolver-problemas-de-empresas-e-ongs.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=100a1a797ae5cdd0a93c762d2b1c8eb6">
#  <img src="//s2.glbimg.com/TXgKL_G4jamM7wgz3yAtuSF9aOk=/346x195/smart/http%3A//i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2019/f/J/HkXCneRLGuDDFR8Zs60Q/alunos-workshop1.png"/>
#  </a>
#  </div>
#  <div class="widget--info__text-container">
#  <div class="widget--info__header">G1</div>
#  <a href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=9&amp;r=1562807439889&amp;u=https%3A%2F%2Fg1.globo.com%2Fsp%2Fsao-carlos-regiao%2Fnoticia%2F2019%2F07%2F10%2Fworkshop-em-sao-carlos-reune-professores-e-alunos-para-resolver-problemas-de-empresas-e-ongs.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=100a1a797ae5cdd0a93c762d2b1c8eb6">
#  <div class="widget--info__title product-color">
#          Workshop em São Carlos reúne professores e alunos para resolver problemas de empresas e ONGs
#        </div>
#  <p class="widget--info__description"><span>... que tenham problemas relacionados a matemática, estatística, <em>ciência</em> de <em>dados</em>, otimização, mecânica dos fluidos e áreas afins...</span> — <span>...
#  O evento realizado pelo Centro de <em>Ciências</em> Matemáticas Aplicadas à Indústria (CeMEAI) é anual e tem o objetivo de aproximar empresas...</span></p>
#  <div class="widget--info__meta">há 3 horas</div>
#  </a>
#  </div>
#  </li>
#  <li class="widget widget--card widget--info" data-position="10">
#  <div class="widget--info__meta--card">
#  <span>G1</span>
#  <span>•</span>
#  <span>há 6 dias</span>
#  </div>
#  <div class="widget--info__media-container">
#  <a class="widget--info__media widget--info__media--video" href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=10&amp;r=1562807439894&amp;u=https%3A%2F%2Fg1.globo.com%2Fsp%2Fsorocaba-jundiai%2Fnoticia%2F2019%2F07%2F03%2Fprocura-por-estagiarios-com-mais-de-30-anos-cresceu-5percent-em-jundiai.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=f69a17ca5c75a4c1db54ba6b4981be07">
#  <img src="//s2.glbimg.com/AyE3Sjiq_JycjqnSkxiSvnEpyiw=/346x195/smart/http%3A//i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2019/Y/G/NZb5rcQfKBgwd0EqCFNw/estagiario.jpg"/>
#  </a>
#  </div>
#  <div class="widget--info__text-container">
#  <div class="widget--info__header">G1</div>
#  <a href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=10&amp;r=1562807439896&amp;u=https%3A%2F%2Fg1.globo.com%2Fsp%2Fsorocaba-jundiai%2Fnoticia%2F2019%2F07%2F03%2Fprocura-por-estagiarios-com-mais-de-30-anos-cresceu-5percent-em-jundiai.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=f69a17ca5c75a4c1db54ba6b4981be07">
#  <div class="widget--info__title product-color">
#          Procura por estagiários com mais de 30 anos cresceu 5% em Jundiaí
#        </div>
#  <p class="widget--info__description"><span>...", explica
#  <em>Dados</em> do Centro de Integração Empresa e Escola (CIEE) mostram que o número de estagiários que passam dos 30 anos cresceu...</span> — <span>... 5%. A área de humanas é a mais procurada por eles. Pedagogia é a preferência, depois vêm direito, serviços sociais e <em>ciências</em>...</span></p>
#  <div class="widget--info__meta">há 6 dias</div>
#  </a>
#  </div>
#  </li>
#  <li class="widget widget--card widget--info" data-position
jpg"/>
#  </a>
#  </div>
#  <div class="widget--info__text-container">
#  <div class="widget--info__header">G1</div>
#  <a href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=13&amp;r=1562807439914&amp;u=https%3A%2F%2Fg1.globo.com%2Fciencia-e-saude%2Fnoticia%2F2019%2F07%2F02%2Fgoverno-expos-detalhes-da-vida-de-13-mil-adolescentes-entre-mais-de-30-mil-dependentes-quimicos-por-3-anos.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=5995676ab3ddde26fa1b952309ff1938">
#  <div class="widget--info__title product-color">
#          Governo expôs detalhes da vida de 1,3 mil adolescentes entre mais de 30 mil dependentes químicos por 3 anos
#        </div>
#  <p class="widget--info__description"><span>... de pessoas com <em>dados</em> privados violados. E quanto mais tempo a informação ficou disponível, maior o <em>dano</em>", explica.
#  Para Gonsales...</span> — <span>Após perguntas de repórter, Ministério da Justiça retirou os <em>dados</em> do site <em>Dados</em> Abertos
#  Pixabay
#  O governo federal expôs por três...</span></p>
#  <div class="widget--info__meta">02/07/2019 21h37</div>
#  </a>
#  </div>
#  </li>
#  <li class="widget widget--card widget--info" data-position="14">
#  <div class="widget--info__meta--card">
#  <span>G1</span>
#  <span>•</span>
#  <span>24/04/2019 16h36</span>
#  </div>
#  <div class="widget--info__media-container">
#  <a class="widget--info__media" href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=14&amp;r=1562807439918&amp;u=https%3A%2F%2Fg1.globo.com%2Fpop-arte%2Fblog%2Fluciano-trigo%2Fpost%2F2019%2F04%2F24%2Fentre-a-ciencia-e-a-ideologia.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=ccc96a90f7f1d0dac74a22f85dddaf3f">
#  <img src="//s2.glbimg.com/G4FFbXX672qRE1tgLopXZc9ZqB4=/346x195/smart/http%3A//i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2019/A/l/Ad17hERrOZta4iBJBQqg/g1-testosterona-capa.jpg"/>
#  </a>
#  </div>
#  <div class="widget--info__text-container">
#  <div class="widget--info__header">G1</div>
#  <a href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=14&amp;r=1562807439920&amp;u=https%3A%2F%2Fg1.globo.com%2Fpop-arte%2Fblog%2Fluciano-trigo%2Fpost%2F2019%2F04%2F24%2Fentre-a-ciencia-e-a-ideologia.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=ccc96a90f7f1d0dac74a22f85dddaf3f">
#  <div class="widget--info__title product-color">
#          Entre a ciência e a ideologia
#        </div>
#  <p class="widget--info__description"><span>... criticar o sexismo da <em>ciência</em>, a autora cai na armadilha do sexismo às avessas, que descarta qualquer <em>dado</em> científico ou opinião...</span> — <span>...: existem diferenças que são culturais, mas também existem diferenças que são inatas. Psicóloga e professora de filosofia da <em>ciência</em>...</span></p>
#  <div class="widget--info__meta">24/04/2019 16h36</div>
#  </a>
#  </div>
#  </li>
#  <li class="widget widget--card widget--info" data-position="15">
#  <div class="widget--info__meta--card">
#  <span>G1</span>
#  <span>•</span>
#  <span>31/05/2019 16h42</span>
#  </div>
#  <div class="widget--info__media-container">
#  <a class="widget--info__media" href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=15&amp;r=1562807439924&amp;u=https%3A%2F%2Fg1.globo.com%2Fro%2Frondonia%2Frondonia-acontece%2Fnoticia%2F2019%2F05%2F31%2Fprojeto-ciencia-cidada-reune-pescadores-na-kaninde-em-porto-velho.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=8c1121bf6f4e4db3e35d366c7b1d2a2d">
#  <img src="//s2.glbimg.com/JzU7wnrHythPIlfRgsIb4KA5jhg=/346x195/smart/http%3A//i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2019/G/a/m6WLh8R9AVPrysy5cSyA/rede-pesca.jpg"/>
#  </a>
#  </div>
#  <div class="widget--info__text-container">
#  <div class="widget--info__header">G1</div>
#  <a href="//g1.globo.com/busca/click?abTestId=ff704ca8-308d-488b-9788-c30c25036e76&amp;abAlternative=info-recency-with-cross-fields&amp;q=ciencia+de+dados&amp;p=15&amp;r=1562807439926&amp;u=https%3A%2F%2Fg1.globo.com%2Fro%2Frondonia%2Frondonia-acontece%2Fnoticia%2F2019%2F05%2F31%2Fprojeto-ciencia-cidada-reune-pescadores-na-kaninde-em-porto-velho.ghtml&amp;abExperiment=bg-g1-info-recency-cross-fields&amp;key=8c1121bf6f4e4db3e35d366c7b1d2a2d">
#  <div class="widget--info__title product-color">
#          Projeto Ciência Cidadã reúne pescadores na Kanindé em Porto Velho
#        </div>
#  <p class="widget--info__description"><span>Projeto <em>Ciência</em> Cidadã reúne pescadores no Centro de formação Kanindé, neste final de semana em Porto Velho
#  Karim Sahib/AFP...</span> — <span>...
#  Começa a partir desta sexta-feira (31) o projeto <em>Ciência</em> Cidadã, realizado pela Ação Ecológica Guaporé.
#  Evento irá reunir cerca de 30...</span></p>
#  <div class="widget--info__meta">31/05/2019 16h42</div>
#  </a>
#  </div>
#  </li>
#  </ul>
#  <div class="pagination widget">
#  <a class="fundo-cor-produto pagination__load-more" href="?q=ciencia+de+dados&amp;page=2">Veja mais</a>
#  </div>
#  </div>
#  </div>
#  </section>, ' ', <footer class="footer fundo-cor-produto">
#  <div class="container" id="glb-rodape">
#  <span>© Copyright 2019 Globo Comunicação e Participações S.A. <a href="http://www.globo.com/privacidade.html">Política de Privacidade</a></span>
#  <ul class="footer__options">
#  <li><a href="https://login.globo.com/login/464">central globo.com</a></li>
#  <li><a href="https://meuperfil.globo.com/perfil/home">assine a globo.com</a></li>
#  <li><a href="http://anuncie.globo.com/redeglobo/">anuncie conosco</a></li>
#  </ul>
#  </div>
#  </footer>, '\n', <input id="algolia_query_id" name="algolia_query_id" type="hidden" value=""/>, '\n', <input id="ab_server_public_url" name="ab_server_public_url" type="hidden" value="https://globo-ab.globo.com/"/>, '\n', <input id="ab_experiment" name="ab_experiment" type="hidden" value="bg-g1-info-recency-cross-fields"/>, '\n', <input id="ab_alternative" name="ab_alternative" type="hidden" value="info-recency-with-cross-fields"/>, '\n', <input id="ab_test_id" name="ab_test_id" type="hidden" value="ff704ca8-308d-488b-9788-c30c25036e76"/>, '\n', <input id="glb_uid" name="glb_uid" type="hidden" value="DMnkzRZgmdYUZ9scdSy67YEIsvbszhZtbVvEefq3CoA="/>, '\n', <input id="info_query_recency" name="info_query_recency" type="hidden" value="info-recencia-refactor-with-cross-field"/>, '\n', <input id="info_query_relevancy" name="info_query_relevancy" type="hidden" value="info-relevancia-stricter-boosted-keywords-stricter-fuzzy"/>, '\n', <script charset="utf-8" src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js" type="text/javascript"></script>, ' ', <script charset="utf-8" src="//s.glbimg.com/bu/es/media/blue/header_padrao-v2/js/busca-debug-2.9.0.js" type="text/javascript"></script>, ' ', <script charset="utf-8" src="//s.glbimg.com/bu/es/media/blue/header_padrao-v2/js/SearchComponents-2.9.0.js" type="text/javascript"></script>, ' ', <script charset="utf-8" src="https://s3.glbimg.com/v1/AUTH_da787d4f4e8d46e3ad76d5fa568fe786/globo-ab/globo-ab-v2.min.js" type="text/javascript"></script>, ' ', <script>
#      glb = window.glb || {}; glb.fnEnvName = "prod" || "qa";
#      glb.menuV2 = window.glb.menuV2 || {};
#  </script>, ' ', <link href="//s.glbimg.com/gl/ba/css/barra-globocom.min.css" rel="stylesheet" type="text/css"/>, ' ', <style>
#  @font-face {
#      font-family: 'g1-iconset';
#      src: url('https://s.glbimg.com/gl/ba/fonts/g1-iconset.eot');
#      src: url('https://s.glbimg.com/gl/ba/fonts/g1-iconset.eot?#iefix') format('embedded-opentype'),
#           url('https://s.glbimg.com/gl/ba/fonts/g1-iconset.woff') format('woff'),
#           url('https://s.glbimg.com/gl/ba/fonts/g1-iconset.ttf') format('truetype'),
#           url('https://s.glbimg.com/gl/ba/fonts/g1-iconset.svg') format('svg');
#      font-weight: normal;
#      font-style: normal
#  }
#
#  #header-produto a.logo {
#      font-family: 'g1-iconset',Helvetica,sans-serif;
#      font-size: 32px;
#  }
#
#  @media only screen and (max-width: 767px) {
#      #header-produto a.logo {
#          font-size: 26px;
#      }
#  }
#
#  #header-produto a.logo span {
#      top: 0;
#      position: relative;
#  }
#  #header-produto a.logo img.logo-produto {
#      display: none;
#  }
#  #header-produto a.logo span:after {
#      content: '\e601';
#  }
#
#  .g1-logo {
#      width: 38px;
#      color: #fff;
#  }
#  </style>, ' ', <style>
#    .header-navegacao-color {
#      color: #C4170C;
#    }
#
#    .gui-color-primary-bg-after:after {
#      background-color: #C4170C;
#    }
#
#    .header-navegacao .logo {
#      width: 38px;
#      height: 23px;
#    }
#
#    .header-navegacao .header-title {
#      padding: 0 38px;
#    }
#
#    @media (max-width: 767px) {
#      .has-not-regua .header-navegacao .header-title {
#        padding: 0 24px 0 80px;
#      }
#    }
#
#    @media (min-width: 768px) {
#      .header-navegacao .logo {
#        width: 53px;
#        height: 32px;
#      }
#
#      .header-navegacao .header-title {
#        padding: 0 95px;
#      }
#
#      .header-navegacao .floating-bar .logo {
#        width: 33px;
#        height: 20px;
#      }
#    }
#
#    @media (min-width: 1065px) {
#      .header-navegacao .header-title {
#        padding: 0 165px;
#      }
#    }
#  </style>, ' ', <script>
#      glb.cdnConfig = glb.cdnConfig || {};
#      glb.cdnConfig.headerConfig = glb.cdnConfig.headerConfig || {
#        brand: {
#            link: "https://g1.globo.com/"
#        },
#
#      };
#
#      glb.headerReady = true;
#      glb.headerCdn = true;
#    </script>, ' ', <style>
#      .menu-navegacao-color-primary{color: #C4170C}
#      .is-menu-desktop .menu-item-link{ font-weight: bolder;}
#  </style>, ' ', <div id="menu-curtain"></div>, ' ', <nav class="menu-container" id="menu-container"> <div class="menu-rounder menu-initial" id="menu-rounder"> <div class="menu-cascade" data-menu-index="0" id="menu-cascade"> <ul class="menu-root menu-level menu-level-0"> <li class="menu-item is-father" id="menu-1-editorias"> <a class="menu-item-link menu-navegacao-color-primary"> <span class="menu-item-title">Editorias<span class="menu-item-arrow menu-navegacao-color-primary"></span></span> </a> <ul class="menu-level menu-submenu menu-submenu-level1 menu-submenu-column-1"> <a class="menu-submenu-title menu-item-back"><span class="menu-item-arrow menu-navegacao-color-primary"></span><span class="regua-navegacao-menu-item">Editorias</span></a> <li class="menu-item is-father" id="menu-2-agro"> <a class="menu-item-link menu-navegacao-color-primary" href="http://g1.globo.com/economia/agronegocios/"> <span class="menu-item-title">Agro<span class="menu-item-arrow menu-navegacao-color-primary"></span></span> </a> <ul class="menu-level menu-submenu menu-submenu-level2 menu-submenu-column-1"> <a class="menu-submenu-title menu-item-back"><span class="menu-item-arrow menu-navegacao-color-primary"></span><span class="regua-navegacao-menu-item">Agro</span></a> <li class="menu-item" id="menu-3-agronegocios"> <a class="menu-item-link menu-navegacao-color-primary" href="https://g1.globo.com/economia/agronegocios/"> <span class="menu-item-title">Agronegócios<span class="menu-item-arrow menu-navegacao-color-primary"></span></span> </a> </li><li class="menu-item" id="menu-3-globo-rural"> <a class="menu-item-link menu-navegacao-color-primary" href="https://g1.globo.com/economia/agronegocios/globo-rural/"> <span class="menu-item-title">Globo Rural<span class="menu-item-arrow menu-navegacao-color-primary"></span></span> </a> </li><li class="menu-item" id="menu-3-a-industria-riqueza-do-brasil"> <a class="menu-item-link menu-navegacao-color-primary" href="https://g1.globo.com/economia/agronegocios/agro-a-industria-riqueza-do-brasil/"> <span class="menu-item-title">A Indústria-Riqueza do Brasil<span class="menu-item-arrow menu-navegacao-color-primary"></span></span> </a> </li> </ul> </li><li class="menu-item is-father" id="menu-2-carros"> <a class="menu-item-link menu-navegacao-color-primary" href="http://g1.globo.com/carros/"> <span class="menu-item-title">Carros<span class="menu-item-arrow menu-navegacao-color-primary"></span></span> </a> <ul class="menu-level menu-submenu menu-submenu-level2 menu-submenu-column-1"> <a class="menu-submenu-title menu-item-back"><span class="menu-item-arrow menu-navegacao-color-primary"></span><span class="regua-navegacao-menu-item">Carros</span></a> <li class="menu-item" id="menu-3-carros-de-a-a-z"> <a class="menu-item-link menu-navegacao-color-primary" href="http://g1.globo.com/carros/a-z/"> <span class="menu-item-title">Carros de A a Z<span class="menu-item-arrow menu-navegacao-color-primary"></span></span> </a> </li><li class="menu-item" id="menu-3-caminhoes"> <a class="menu-item-link menu-navegacao-color-primary" href="http://g1.globo.com/carros/caminhoes/"> <span class="menu-item-title">Caminhões<span class="menu-item-arrow menu-navegacao-color-primary"></span></span> </a> </li><li class="menu-item" id="menu-3-carros-eletricos-e-hibridos"> <a class="menu-item-link menu-navegacao-color-primary" href="https://g1.globo.com/carros/carros-eletricos-e-hibridos/"> <span class="menu-item-title">Carros elétricos e híbridos<span class="menu-item-arrow menu-navegacao-color-primary"></span></span> </a> </li><li class="menu-item" id="menu-3-motos"> <a class="menu-item-link menu-navegacao-color-primary" href="http://g1.globo.com/carros/motos/"> <span class="menu-item-title">Motos<span class="menu-item-arrow menu-navegacao-color-primary"></span></span> </a> </li><li class="menu-item" id="menu-3-ipva"> <a class="menu-item-link menu-navegacao-color-primary" href="http://g1.globo.com/carros/assuntos/ipva.html"> <span class="menu-it ...
#  //<![CDATA[
#
#
#  !function(e){function n(o){if(t[o])return t[o].exports;var r=t[o]={exports:{},id:o,loaded:!1};return e[o].call(r.exports,r,r.exports,n),r.loaded=!0,r.exports}var t={};n.m=e,n.c=t,n.p="",n(0)}([function(e,n,t){e.exports=t(7)},,,function(e,n,t){var o,o;Object.defineProperty(n,"__esModule",{value:!0}),glb.headerError||function e(n,t,r){function i(a,c){if(!t[a]){if(!n[a]){var l="function"==typeof o&&o;if(!c&&l)return o(a,!0);if(s)return s(a,!0);var u=new Error("Cannot find module '"+a+"'");throw u.code="MODULE_NOT_FOUND",u}var d=t[a]={exports:{}};n[a][0].call(d.exports,function(e){var t=n[a][1][e];return i(t||e)},d,d.exports,e,n,t,r)}return t[a].exports}for(var s="function"==typeof o&&o,a=0;a<r.length;a++)i(r[a]);return i}({1:[function(e,n,t){var o;o={components:["common"],typeFiles:["css","js","sprites","json"],fnExpires:{prod:60,staging:60,qa:1,local:1},fnCdnBaseUrls:{prod:"https://s3.glbimg.com/cdn/fn/",staging:"https://s3.glbimg.com/cdn_staging/fn/",qa:"https://s3.glbimg.qa.globoi.com/cdn/fn/",local:"static/"},fnConfigFiles:{prod:"config/latest/config-fn.min.json",staging:"config/latest/config-fn.min.json",qa:"config/latest/config-fn.min.json",local:"config/config-fn.local.json"},fnInternalHosts:[{pattern:"globocom(.admin|.be)?(.qa|.dev)?.globoi.com",host:"www.globo.com"},{pattern:"g1(.admin|.be)?(.qa|.dev)?.globoi.com",host:"g1.globo.com"},{pattern:"techtudo(-v2)?(.admin|.be)?(.qa|.qa01|.dev)?.globoi.com",host:"www.techtudo.com.br"},{pattern:"gshow(.admin|.be)?(.qa|.dev)?.globoi.com",host:"gshow.globo.com"},{pattern:"globoesporte(.admin|.be)?(.qa|.dev)?.globoi.com",host:"globoesporte.globo.com"},{pattern:"famosos(.admin|.be)?(.qa|.dev)?.globoi.com",host:"famosos.globo.com"},{pattern:"dev.beta(.qa)?.globoi.com",host:"dev.beta.globo.com"}],fnDevice:"mobile",debug:!1,fnEnv:"prod",defaultHost:"famosos.globo.com"},void 0!==n&&n.exports&&(n.exports=o)},{}],2:[function(e,n,t){var o,r,i,s;s=function(){return/MobApp_Android|MobApp_iOS|MobApp_WP/},i=function(){return window.getUserAgent?window.getUserAgent():window.navigator.userAgent},r=function(){var e,n,t,o,r;o=i(),r=o.split(" ");for(t in r)if(e=r[t],s().test(e))return n=e.split("/"),{name:n[0].replace("_"," "),version:n[1],frameworkVersion:n[2]};return null},o=function(){if(window.glb=window.glb||{},!glb.extractAppFromUserAgent){glb.extractAppFromUserAgent=r,glb.nativeAppInfo=r(),glb.nativeAppType=null;try{localStorage.removeItem("glbOnApp")}catch(e){e}if(null!==window.glb.nativeAppInfo)if(window.glb.nativeAppInfo.frameworkVersion){if(parseInt(window.glb.nativeAppInfo.frameworkVersion,10)>=1){manageElementClasses.hasClass(document.documentElement,"glb-on-app")||(document.documentElement.className+=" glb-on-app");try{localStorage.setItem("glbOnApp",glb.nativeAppInfo.frameworkVersion)}catch(e){e}glb.nativeAppType="master-app"}}else manageElementClasses.hasClass(document.documentElement,"glb-on-app-comnio")||(document.documentElement.className+=" glb-on-app-comnio"),glb.nativeAppType="comnio-app"}},void 0!==n&&n.exports&&(n.exports=o)},{}],3:[function(e,n,t){var o,r,i,s,a;window.glb=window.glb||{},a=e("../../globo-cdn-src/scripts/tiny-basket.coffee"),e("../../globo-cdn-src/scripts/common/__custom-event.coffee"),r=window.isArray,s=window.stringStartsWith,glb.extendArrays=function(e,n){if(r(e)&&r(n))return Array.prototype.push.apply(e,n),e},glb.addGlbOnAppClass=e("../../globo-cdn-src/scripts/app/__master-app-addclass.coffee"),glb.addHasReguaClass=e("../../globo-cdn-src/scripts/regua/__regua-navegacao-addclass.coffee"),glb.cdnConfig=e("../../globo-cdn-src/scripts/__cdn-configs.coffee"),glb.createProductColorCss=function(e){return a.injectStylesheet("text/css",".menu-navegacao-color { color: "+e+"; }","fn-menu-color-default")},glb.getCurrentInternalHost=function(e){var n,t,o,r,i,s;for(s=glb.cdnConfig.fnInternalHosts,n=0,r=s.length;n<r;n++)if(t=s[n],o=new RegExp(t.pattern),i=t.host,o.test(e))return i;return e},glb.getCurrentProduct=function(e){var n,t,o;return null!=glb.fnProduct?glb.fnPr ...
#
#  //]]>
#  </script>, ' ']
